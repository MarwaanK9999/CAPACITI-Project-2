# %%
import pandas as pd

# %%
data = pd.read_csv('owid-covid-data.csv')

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
data.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 202181      ZWE    Africa  Zimbabwe  2022-07-14     256047.0       66.0
# 202182      ZWE    Africa  Zimbabwe  2022-07-15     256083.0       36.0
# 202183      ZWE    Africa  Zimbabwe  2022-07-16     256083.0        0.0
# 202184      ZWE    Africa  Zimbabwe  2022-07-17     256083.0        0.0
# 202185      ZWE    Africa  Zimbabwe  2022-07-18     256083.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 202181              34.571        5566.0         1.0                0.857
# 202182              27.429        5566.0         0.0                0.571
# 202183              22.714        5566.0         0.0                0.429
# 202184              20.571        5566.0         0.0                0.286
# 202185              18.571        5566.0         0.0                0.143
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 202181  ...             1.6          30.7                  36.791
# 202182  ...             1.6          30.7                  36.791
# 202183  ...             1.6          30.7                  36.791
# 202184  ...             1.6          30.7                  36.791
# 202185  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 202181                         1.7            61.49                    0.571
# 202182                         1.7            61.49                    0.571
# 202183                         1.7            61.49                    0.571
# 202184                         1.7            61.49                    0.571
# 202185                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 202181                                   NaN                          NaN
# 202182                                   NaN                          NaN
# 202183                                   NaN                          NaN
# 202184                                   NaN                          NaN
# 202185                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 202181               NaN                                      NaN
# 202182               NaN                                      NaN
# 202183               NaN                                      NaN
# 202184               NaN                                      NaN
# 202185               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
data = pd.read_csv('owid-covid-data.csv', usecols=['iso_code'])
data.tail()
# Out:
#        iso_code
# 202181      ZWE
# 202182      ZWE
# 202183      ZWE
# 202184      ZWE
# 202185      ZWE

# %%
data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]
data.head()
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 875        AFG      Asia  Afghanistan  2022-07-18     183687.0      115.0
# 1762  OWID_AFR       NaN       Africa  2022-07-18   12176520.0     5404.0
# 2637       ALB    Europe      Albania  2022-07-18     293917.0        NaN
# 3512       DZA    Africa      Algeria  2022-07-18     266487.0       42.0
# 4381       AND    Europe      Andorra  2022-07-18      45061.0      390.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 875               59.857        7733.0         2.0                0.714  ...
# 1762            6809.143      255586.0        42.0               33.571  ...
# 2637                 NaN        3517.0         0.0                0.429  ...
# 3512              30.429        6875.0         0.0                0.000  ...
# 4381              55.714         153.0         0.0                0.000  ...
#
#       female_smokers  male_smokers  handwashing_facilities  \
# 875              NaN           NaN                  37.746
# 1762             NaN           NaN                     NaN
# 2637             7.1          51.2                     NaN
# 3512             0.7          30.4                  83.741
# 4381            29.0          37.8                     NaN
#
#       hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 875                         0.50            64.83                    0.511
# 1762                         NaN              NaN                      NaN
# 2637                        2.89            78.57                    0.795
# 3512                        1.90            76.88                    0.748
# 4381                         NaN            83.73                    0.868
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 875                                    NaN                          NaN
# 1762                                   NaN                          NaN
# 2637                                   NaN                          NaN
# 3512                                   NaN                          NaN
# 4381                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 875                NaN                                      NaN
# 1762               NaN                                      NaN
# 2637               NaN                                      NaN
# 3512               NaN                                      NaN
# 4381               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

# x axis values 
x = data['total_deaths']
# corresponding y axis values 
y = data['location'] 

plt.figure(figsize=(25, 45))

# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('Total Number of Deaths') 
# naming the y axis 
plt.ylabel('Country') 
 
    
    
# giving a title to my graph 
plt.title('Total Deaths Around The World') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

# x axis values 
x = data['total_cases']
# corresponding y axis values 
y = data['location'] 

plt.figure(figsize=(25, 45))

# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('Total Number of Cases') 
# naming the y axis 
plt.ylabel('Country') 
 
    
    
# giving a title to my graph 
plt.title('Total Cases Around The World') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

data1 = data[(data["location"] == "High income")]
data2 = data[(data["location"] == "Upper middle income")]
data3 = data[(data["location"] == "Lower middle income")]

frames = [data1, data2, data3]

result = pd.concat(frames)

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='location'>

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

data1 = data[(data["location"] == "Europe")]
data2 = data[(data["location"] == "Asia")]
data3 = data[(data["location"] == "Africa")]
data4 = data[(data["location"] == "North America")]
data5 = data[(data["location"] == "South America")]
data6 = data[(data["location"] == "Oceana")]
data7 = data[(data["location"] == "World")]

frames = [data1, data2, data3, data4, data5, data6, data7]

result = pd.concat(frames)

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='location'>

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
dataBeginning = data[(data["date"] == "2020-02-24")]
dataLatest = data[(data["date"] == "2022-07-18")]

data1 = dataBeginning[(dataBeginning["location"] == "World")]
data2 = dataLatest[(dataLatest["location"] == "World")]

frames = [data1, data2]

result = pd.concat(frames)

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='location'>
