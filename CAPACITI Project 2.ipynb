# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('owid-covid-data.csv')

# %%
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
data.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 202181      ZWE    Africa  Zimbabwe  2022-07-14     256047.0       66.0
# 202182      ZWE    Africa  Zimbabwe  2022-07-15     256083.0       36.0
# 202183      ZWE    Africa  Zimbabwe  2022-07-16     256083.0        0.0
# 202184      ZWE    Africa  Zimbabwe  2022-07-17     256083.0        0.0
# 202185      ZWE    Africa  Zimbabwe  2022-07-18     256083.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 202181              34.571        5566.0         1.0                0.857
# 202182              27.429        5566.0         0.0                0.571
# 202183              22.714        5566.0         0.0                0.429
# 202184              20.571        5566.0         0.0                0.286
# 202185              18.571        5566.0         0.0                0.143
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
data = pd.read_csv('owid-covid-data.csv', usecols=['iso_code'])
data.tail()
# Out:
#        iso_code
# 202181      ZWE
# 202182      ZWE
# 202183      ZWE
# 202184      ZWE
# 202185      ZWE

# %%
data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]
data.head(200)
# Out:
#         iso_code      continent     location        date  total_cases  \
# 875          AFG           Asia  Afghanistan  2022-07-18     183687.0
# 1762    OWID_AFR            NaN       Africa  2022-07-18   12176520.0
# 2637         ALB         Europe      Albania  2022-07-18     293917.0
# 3512         DZA         Africa      Algeria  2022-07-18     266487.0
# 4381         AND         Europe      Andorra  2022-07-18      45061.0
# ...          ...            ...          ...         ...          ...
# 172715       LKA           Asia    Sri Lanka  2022-07-18     664510.0
# 173573       SDN         Africa        Sudan  2022-07-18      62872.0
# 174430       SUR  South America     Suriname  2022-07-18      80919.0
# 175329       SWE         Europe       Sweden  2022-07-18    2528166.0
# 176204       CHE         Europe  Switzerland  2022-07-18    3861756.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
location_array = data[['location']].to_numpy()

print(location_array)
# Out:
# [['Afghanistan']
#  ['Africa']
#  ['Albania']
#  ['Algeria']
#  ['Andorra']
#  ['Angola']
#  ['Anguilla']
#  ['Antigua and Barbuda']
#  ['Argentina']
#  ['Armenia']
#  ['Aruba']
#  ['Asia']
#  ['Australia']
#  ['Austria']
#  ['Azerbaijan']
#  ['Bahamas']
#  ['Bahrain']
#  ['Bangladesh']
#  ['Barbados']
#  ['Belarus']
#  ['Belgium']
#  ['Belize']
#  ['Benin']
#  ['Bermuda']
#  ['Bhutan']
#  ['Bolivia']
#  ['Bonaire Sint Eustatius and Saba']
#  ['Bosnia and Herzegovina']
#  ['Botswana']
#  ['Brazil']
#  ['British Virgin Islands']
#  ['Brunei']
#  ['Bulgaria']
#  ['Burkina Faso']
#  ['Burundi']
#  ['Cambodia']
#  ['Cameroon']
#  ['Canada']
#  ['Cape Verde']
#  ['Cayman Islands']
#  ['Central African Republic']
#  ['Chad']
#  ['Chile']
#  ['China']
#  ['Colombia']
#  ['Comoros']
#  ['Congo']
#  ['Cook Islands']
#  ['Costa Rica']
#  ["Cote d'Ivoire"]
#  ['Croatia']
#  ['Cuba']
#  ['Curacao']
#  ['Cyprus']
#  ['Czechia']
#  ['Democratic Republic of Congo']
#  ['Denmark']
#  ['Djibouti']
# ...

# %%
print(location_array.shape)

newarr = np.where(location_array == "Brazil")

print(newarr)
print(location_array[29])
# Out:
# (229, 1)
# (array([29], dtype=int64), array([0], dtype=int64))
# ['Brazil']

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

# x axis values 
x = data['total_deaths']
# corresponding y axis values 
y = data['location'] 

plt.figure(figsize=(25, 45))

# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('Total Number of Deaths') 
# naming the y axis 
plt.ylabel('Country') 
 
    
    
# giving a title to my graph 
plt.title('Total Deaths Around The World') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

# x axis values 
x = data['total_cases']
# corresponding y axis values 
y = data['location'] 

plt.figure(figsize=(25, 45))

# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('Total Number of Cases') 
# naming the y axis 
plt.ylabel('Country') 
 
    
    
# giving a title to my graph 
plt.title('Total Cases Around The World') 
  
# function to show the plot 
plt.show()

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

data1 = data[(data["location"] == "High income")]
data2 = data[(data["location"] == "Upper middle income")]
data3 = data[(data["location"] == "Lower middle income")]

frames = [data1, data2, data3]

result = pd.concat(frames)

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], kind="bar", title="Comparison of Data in Certain Income Classes in Countries", figsize=(9, 8))
# Out:
# <AxesSubplot:title={'center':'Comparison of Data in certain Income Classes in Countries'}, xlabel='location'>

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

data1 = data[(data["location"] == "Europe")]
data2 = data[(data["location"] == "Asia")]
data3 = data[(data["location"] == "Africa")]
data4 = data[(data["location"] == "North America")]
data5 = data[(data["location"] == "South America")]
data6 = data[(data["location"] == "Oceana")]
data7 = data[(data["location"] == "World")]

frames = [data1, data2, data3, data4, data5, data6, data7]

result = pd.concat(frames)

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], title="Comparison of Data in Different Continents", kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:title={'center':'Comparison of Data in Different Continents'}, xlabel='location'>

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
dataBeginning = data[(data["date"] == "2020-02-24")]
dataLatest = data[(data["date"] == "2022-07-18")]

data1 = dataBeginning[(dataBeginning["location"] == "World")]
data2 = dataLatest[(dataLatest["location"] == "World")]

frames = [data1, data2]

result = pd.concat(frames)

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], kind="bar", title="Comparison of Data Beginning and Current Figures", figsize=(9, 8))

df = pd.DataFrame(result, columns=["location", "total_cases", "total_deaths", "new_deaths"])
df.plot(x="location", y=["total_cases", "total_deaths", "new_deaths"], kind="hist", title="Comparison of Data Beginning and Current Figures", figsize=(9, 8))
# Out:
# <AxesSubplot:title={'center':'Comparison of Data Beginning and Current Figures'}, ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

data1 = data[(data["location"] == "World")]

df = pd.DataFrame(data1, columns=["location", "female_smokers", "male_smokers"])
df.plot(x="location", y=["female_smokers", "male_smokers"], title="Comparison Between Female and Male Smokers in Different Continents", kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:title={'center':'Comparison Between Female and Male in Different Continents'}, xlabel='location'>

# %%
import matplotlib.pyplot as plt 

data = pd.read_csv('owid-covid-data.csv')
data = data[(data["date"] == "2022-07-18")]

data1 = data[(data["location"] == "World")]

df = pd.DataFrame(data1, columns=["location", "handwashing_facilities", "hospital_beds_per_thousand"])
df.plot(x="location", y=["handwashing_facilities", "hospital_beds_per_thousand"], title="Comparison Between Female and Male Smokers in Different Continents", kind="bar", figsize=(9, 8))
# Out:
# <AxesSubplot:title={'center':'Comparison Between Female and Male Smokers in Different Continents'}, xlabel='location'>
